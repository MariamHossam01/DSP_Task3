# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
import os
import pandas as pd
import librosa
import speech_recognition as sr
import numpy as np
from sklearn import metrics

# %%
filelist = os.listdir('..\\dataset2\\Dina Mostafa')
df_dina = pd.DataFrame(filelist)
df_dina['label']='0'
df_dina = df_dina.rename(columns={0:'file'})
df_dina
# Out:
#                 file label
# 0    h_close_(1).wav     0
# 1   h_close_(10).wav     0
# 2   h_close_(11).wav     0
# 3   h_close_(12).wav     0
# 4   h_close_(13).wav     0
# 5   h_close_(14).wav     0
# 6   h_close_(15).wav     0
# 7    h_close_(2).wav     0
# 8    h_close_(3).wav     0
# 9    h_close_(4).wav     0
# 10   h_close_(5).wav     0
# 11   h_close_(6).wav     0
# 12   h_close_(7).wav     0
# 13   h_close_(8).wav     0
# 14   h_close_(9).wav     0
# 15    h_open_(1).wav     0
# 16   h_open_(10).wav     0
# 17   h_open_(11).wav     0
# 18   h_open_(12).wav     0
# 19   h_open_(13).wav     0
# 20   h_open_(14).wav     0
# 21   h_open_(15).wav     0
# 22    h_open_(2).wav     0
# 23    h_open_(3).wav     0
# 24    h_open_(4).wav     0
# 25    h_open_(5).wav     0
# 26    h_open_(6).wav     0
# 27    h_open_(7).wav     0
# 28    h_open_(8).wav     0
# 29    h_open_(9).wav     0
# 30   h_wrong_(1).wav     0
# 31  h_wrong_(10).wav     0
# 32   h_wrong_(2).wav     0
# 33   h_wrong_(3).wav     0
# 34   h_wrong_(4).wav     0
# 35   h_wrong_(5).wav     0
# 36   h_wrong_(6).wav     0
# 37   h_wrong_(7).wav     0
# 38   h_wrong_(8).wav     0
# 39   h_wrong_(9).wav     0

# %%
filelist= os.listdir('..\\dataset2\\Kareeman')
df_kareeman = pd.DataFrame(filelist)
df_kareeman['label']='1'
df_kareeman = df_kareeman.rename(columns={0:'file'})
df_kareeman
# Out:
#                  file label
# 0    L_close_(14).wav     1
# 1   L_close_(15) .wav     1
# 2     L_close_(2).wav     1
# 3     L_close_(3).wav     1
# 4     L_close_(4).wav     1
# 5     L_close_(5).wav     1
# 6     L_close_(6).wav     1
# 7     L_close_(7).wav     1
# 8     L_close_(8).wav     1
# 9     L_close_(9).wav     1
# 10     L_open_(1).wav     1
# 11    L_open_(10).wav     1
# 12    L_open_(11).wav     1
# 13    L_open_(12).wav     1
# 14    L_open_(13).wav     1
# 15    L_open_(14).wav     1
# 16    L_open_(15).wav     1
# 17     L_open_(2).wav     1
# 18     L_open_(3).wav     1
# 19     L_open_(4).wav     1
# 20     L_open_(5).wav     1
# 21     L_open_(6).wav     1
# 22     L_open_(7).wav     1
# 23     L_open_(8).wav     1
# 24     L_open_(9).wav     1

# %%
filelist = os.listdir('..\\dataset2\\Mariam')
df_mariam = pd.DataFrame(filelist)
df_mariam['label']='2'
df_mariam = df_mariam.rename(columns={0:'file'})
df_mariam
# Out:
#                 file label
# 0    b_close_(1).wav     2
# 1   b_close_(10).wav     2
# 2    b_close_(2).wav     2
# 3    b_close_(3).wav     2
# 4    b_close_(4).wav     2
# 5    b_close_(5).wav     2
# 6    b_close_(6).wav     2
# 7    b_close_(7).wav     2
# 8    b_close_(8).wav     2
# 9    b_close_(9).wav     2
# 10    b_open_(1).wav     2
# 11   b_open_(10).wav     2
# 12    b_open_(2).wav     2
# 13    b_open_(3).wav     2
# 14    b_open_(4).wav     2
# 15    b_open_(5).wav     2
# 16    b_open_(6).wav     2
# 17    b_open_(7).wav     2
# 18    b_open_(8).wav     2
# 19    b_open_(9).wav     2

# %%
filelist = os.listdir('..\\dataset2\\Nada')
df_nada = pd.DataFrame(filelist)
df_nada['label']='3'
df_nada = df_nada.rename(columns={0:'file'})
df_nada
# Out:
# Empty DataFrame
# Columns: [label]
# Index: []

# %%
filelist=os.listdir('..\\dataset2\\Others')
#read them into pandas
df_others = pd.DataFrame(filelist)
df_others['label']='4'
df_others = df_others.rename(columns={0:'file'})
df_others
# Out:
#                file label
# 0   a_close_(1).wav     4
# 1   a_close_(2).wav     4
# 2   a_close_(3).wav     4
# 3   a_close_(4).wav     4
# 4   a_close_(5).wav     4
# 5    a_open_(1).wav     4
# 6    a_open_(2).wav     4
# 7    a_open_(3).wav     4
# 8    a_open_(4).wav     4
# 9    a_open_(5).wav     4
# 10  e_close_(1).wav     4
# 11  e_close_(2).wav     4
# 12  e_close_(3).wav     4
# 13  e_close_(4).wav     4
# 14   e_open_(1).wav     4
# 15   e_open_(2).wav     4
# 16   e_open_(3).wav     4
# 17   e_open_(4).wav     4
# 18   e_open_(5).wav     4
# 19  o_close_(1).wav     4
# 20  o_close_(2).wav     4
# 21  o_close_(3).wav     4
# 22  o_close_(4).wav     4
# 23  o_close_(5).wav     4
# 24   o_open_(1).wav     4
# 25   o_open_(2).wav     4
# 26   o_open_(3).wav     4
# 27   o_open_(4).wav     4
# 28   o_open_(5).wav     4
# 29  r_open_ (1).wav     4
# 30  r_open_ (2).wav     4
# 31  r_open_ (3).wav     4
# 32  r_open_ (4).wav     4
# 33  r_open_ (5).wav     4

# %%
df = pd.concat([df_dina, df_kareeman, df_mariam, df_nada, df_others], ignore_index=True)
df.head()
# Out:
#                file label
# 0   h_close_(1).wav     0
# 1  h_close_(10).wav     0
# 2  h_close_(11).wav     0
# 3  h_close_(12).wav     0
# 4  h_close_(13).wav     0

# %%
def extract_features(files,name="all"):
    try:
        # Sets the name to be the path to where the file is in my computer
        file_name = os.path.join(os.path.abspath('dataset2\{}').format(name)+ ('\\') +str(files['file']))

        # Loads the audio file as a floating point time series and assigns the default sample rate
        # Sample rate is set to 22050 by default
        
        X, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        
        # Generate Mel-frequency cepstral coefficients (MFCCs) from a time series 
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)

        # Generates a Short-time Fourier transform (STFT) to use in the chroma_stft
        stft = np.abs(librosa.stft(X))

        # Computes a chromagram from a waveform or power spectrogram.
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)

        # Computes a mel-scaled spectrogram.
        mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)

        # Computes spectral contrast
        contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)

        # Computes the tonal centroid features (tonnetz)
        tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),
        sr=sample_rate).T,axis=0)

        # We add also the classes of each file as a label at the end
        label = files.label
        
    except:
        print(files)

    return mfccs, chroma, mel, contrast, tonnetz, label

# %%
def feat(features_label):
    features = []
    for i in range(0, len(features_label)):
        features.append(np.concatenate((features_label[i][0], features_label[i][1], 
                features_label[i][2], features_label[i][3],
                features_label[i][4]), axis=0))
    return features

# %%
features_label = df.apply(extract_features, axis=1)
features=feat(features_label)
# Out:
# file     h_close_(1).wav
# label                  0
# Name: 0, dtype: object
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [110], line 1
# ----> 1 features_label = df.apply(extract_features, axis=1)
#       2 features=feat(features_label)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:9558, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9547 from pandas.core.apply import frame_apply
#    9549 op = frame_apply(
#    9550     self,
#    9551     func=func,
#    (...)
#    9556     kwargs=kwargs,
#    9557 )
# -> 9558 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:741, in FrameApply.apply(self)
#     738 elif self.raw:
#     739     return self.apply_raw()
# --> 741 return self.apply_standard()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:868, in FrameApply.apply_standard(self)
#     867 def apply_standard(self):
# --> 868     results, res_index = self.apply_series_generator()
#     870     # wrap results
#     871     return self.wrap_results(results, res_index)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\apply.py:884, in FrameApply.apply_series_generator(self)
#     881 with option_context("mode.chained_assignment", None):
#     882     for i, v in enumerate(series_gen):
#     883         # ignore SettingWithCopy here in case the user mutates
# --> 884         results[i] = self.f(v)
#     885         if isinstance(results[i], ABCSeries):
#     886             # If we have a view on v, we need to make a copy because
#     887             #  series_generator will swap out the underlying data
#     888             results[i] = results[i].copy(deep=False)
#
# Cell In [108], line 36, in extract_features(files, name)
#      33 except:
#      34     print(files)
# ---> 36 return mfccs, chroma, mel, contrast, tonnetz, label
#
# UnboundLocalError: local variable 'mfccs' referenced before assignment

# %%
X_train, X_test, y_train, y_test = train_test_split(features,df['label'], test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(criterion="entropy", max_depth=5)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
filelist = os.listdir('dataset2\\test') 

#read them into pandas
df_test = pd.DataFrame(filelist)
df_test = df_test.rename(columns={0:'file'})
df_test

# %%
def extract_features_test(files,name="test"):
    try:
        # Sets the name to be the path to where the file is in my computer
        file_name = os.path.join(os.path.abspath('dataset2/{}').format(name)+ ('\\') +str(files['file']))

        # Loads the audio file as a floating point time series and assigns the default sample rate
        # Sample rate is set to 22050 by default
        
        X, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        
        # Generate Mel-frequency cepstral coefficients (MFCCs) from a time series 
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)

        # Generates a Short-time Fourier transform (STFT) to use in the chroma_stft
        stft = np.abs(librosa.stft(X))

        # Computes a chromagram from a waveform or power spectrogram.
        chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)

        # Computes a mel-scaled spectrogram.
        mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)

        # Computes spectral contrast
        contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)

        # Computes the tonal centroid features (tonnetz)
        tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),
        sr=sample_rate).T,axis=0)

    except:
        print(files)

    return mfccs, chroma, mel, contrast, tonnetz

# %%
features_label2 = df_test.apply(extract_features_test, axis=1)
features=feat(features_label2)
y_pred = clf.predict(features)
y_pred
